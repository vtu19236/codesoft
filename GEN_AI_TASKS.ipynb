# %% [markdown]
# <a href="https://colab.research.google.com/github/vtu19236/codesoft/blob/main/GEN_AI_TASKS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#task 1
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

def generate_text(prompt, model_name="gpt2-medium", max_length=100, temperature=1.0):
    # Load pre-trained model and tokenizer
    tokenizer = GPT2Tokenizer.from_pretrained(model_name)
    model = GPT2LMHeadModel.from_pretrained(model_name)

    # Encode prompt text
    input_ids = tokenizer.encode(prompt, return_tensors="pt")

    # Generate text
    output = model.generate(input_ids, max_length=max_length, temperature=temperature, num_return_sequences=1)

    # Decode and return generated text
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return generated_text

# Example usage
prompt = "Once upon a time"
generated_text = generate_text(prompt)
print("Generated Text:")
print(generated_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Text:
# Once upon a time, there was a man who lived in a village called Krakow. He was a very good man, and he was very kind to his children. One day, he was walking along the road, and he saw a woman walking by. He asked her if she was his daughter. She said yes, and she said that she was his daughter. He asked her if she was his wife. She said yes, and she said that she was his wife. He asked her

# %% [markdown]
# **Task 2**

# %%
#task 2
# !pip install torch==1.13.1 torchvision==0.14.1 torchaudio==0.13.1 torchdata==0.5.1 torchtext==0.14.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 34.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 43.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 80.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 75.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 56.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 76.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1+cu121
#     Uninstalling torch-2.2.1+cu121:
#       Successfully uninstalled torch-2.2.1+cu121
#   Attempting uninstall: torchvision
# ...

# %%
# !pip install -qqq git+https://github.com/huggingface/diffusers.git
# !pip install -q accelerate transformers ftfy bitsandbytes==0.35.0 gradio natsort safetensors xformers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.7/222.7 MB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.4/314.4 kB 30.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 14.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 74.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 8.0 MB/s eta 0:00:00
# ...

# %%
import torch
from diffusers import StableDiffusionImg2ImgPipeline

device = "cuda"
pipe = StableDiffusionImg2ImgPipeline.from_pretrained("runwayml/stable-diffusion-v1-5", torch_dtype=torch.float16)
pipe = pipe.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# safety_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# ...

# %%
pipe.enable_attention_slicing()
pipe.enable_xformers_memory_efficient_attention()

# %%
seed = 777

# %%
from PIL import Image
init_img = Image.open('/content/dog-4390885_640.jpg').convert("RGB")
init_img = init_img.resize((512, 512))
init_img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
prompt = 'photgraph of an dog'

# %%
prompt = "oil painting of a dog on a grass field, blue sky and clouds in the background"
generator = torch.Generator(device=device).manual_seed(seed)
image = pipe(prompt=prompt, image=init_img, strength=0.8, generator=generator).images[0]
image
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# **Task 3**

# %%
#task 3
from transformers import pipeline

story_gen = pipeline("text-generation", "pranavpsv/gpt2-genre-story-generator")
print(story_gen("<BOS> <superhero> Batman"))
# Out:
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/510M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/166 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/203 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [{'generated_text': "<BOS> <superhero> Batman's story begins with a group of assassins attempting to steal money from the Batcave. Two have different approaches when they encounter each other: The first is the Batgirl and her fellow assassins, Selina Kyle and Ra's al"}]

# %%
# !pip install -q transformers

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

torch_device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained("gpt2")

# add the EOS token as PAD token to avoid warnings
model = AutoModelForCausalLM.from_pretrained("gpt2", pad_token_id=tokenizer.eos_token_id).to(torch_device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
# encode context the generation is conditioned on
model_inputs = tokenizer('The girl is playing with her dog', return_tensors='pt').to(torch_device)

# generate 40 new tokens
greedy_output = model.generate(**model_inputs, max_new_tokens=40)

print("Output:\n" + 100 * '-')
print(tokenizer.decode(greedy_output[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ----------------------------------------------------------------------------------------------------
# The girl is playing with her dog, and she's trying to get her dog to stop.
#
# "I'm trying to get her to stop, but she's not going to stop," she said.
#
# The girl is

# %%
# set seed to reproduce results. Feel free to change the seed though to get different results
from transformers import set_seed
set_seed(42)

# activate sampling and deactivate top_k by setting top_k sampling to 0
sample_output = model.generate(
    **model_inputs,
    max_new_tokens=40,
    do_sample=True,
    top_k=0
)

print("Output:\n" + 100 * '-')
print(tokenizer.decode(sample_output[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ----------------------------------------------------------------------------------------------------
# The girl is playing with her dog, the stray that got snuffed out and had to be euthanized. Mather says "she was 6 months old her first time playing with her puppy." That dog is a Kikato

# %% [markdown]
# <h1>TASK 4:LOGO GENERATION USING LORA</h1>
#
# ---

# %%
import requests
import io
from PIL import Image
import matplotlib.pyplot as plt

API_URL = "https://api-inference.huggingface.co/models/ygohel18/lora-gen-logo"
headers = {"Authorization": "Bearer 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"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.content

# Prompt the user for the input
user_input = input("Enter a prompt (e.g., 'Astronaut riding a horse'): ")

image_bytes = query({
    "inputs": user_input,
})

# Open the image using PIL
image = Image.open(io.BytesIO(image_bytes))

# Display the image using matplotlib
plt.imshow(image)
plt.axis('off')  # Turn off axis
plt.show()
# Out:
# Enter a prompt (e.g., 'Astronaut riding a horse'): "Geometric logo for a construction company"

# %% [markdown]
# **Task 5**

# %%
#task 5
import random

# Define a dataset of example recipes
recipes = [
    {
        "name": "Spaghetti Carbonara",
        "cuisine": "Italian",
        "ingredients": ["spaghetti", "eggs", "bacon", "Parmesan cheese", "black pepper"],
        "instructions": "Boil spaghetti until al dente. In a separate pan, fry bacon until crispy. Beat eggs and mix with grated Parmesan cheese. Drain spaghetti and toss with egg mixture, then add bacon and black pepper. Serve hot.",
        "dietary_restrictions": ["non-vegetarian"]
    },
    {
        "name": "Fried Rice",
        "cuisine": "Chinese",
        "ingredients": ["cooked rice", "vegetables (carrot, peas, bell peppers)", "eggs", "soy sauce", "garlic", "ginger", "green onions", "oil", "salt"],
        "instructions": "Heat oil in a pan. Add minced garlic and ginger, sauté until fragrant. Add chopped vegetables and cook until tender. Push vegetables to one side, add beaten eggs, scramble until cooked. Add cooked rice, soy sauce, and salt. Mix well, cook until heated through. Garnish with chopped green onions. Serve hot.",
        "dietary_restrictions": ["vegetarian", "non-vegetarian"]
    },
]

# Additional Indian recipes
indian_recipes = [
    {
        "name": "Egg Curry",
        "cuisine": "Indian",
        "ingredients": ["eggs", "onion", "tomato", "ginger", "garlic", "chili powder", "turmeric", "coriander powder", "garam masala", "salt", "oil", "cilantro"],
        "instructions": "Boil eggs and peel them. In a pan, heat oil and fry sliced onion until golden brown. Add chopped tomatoes, ginger, and garlic paste. Cook until tomatoes are soft. Add chili powder, turmeric, coriander powder, garam masala, and salt. Cook until oil separates. Cut boiled eggs in half and add to the gravy. Cook for a few minutes. Garnish with chopped cilantro. Serve hot with rice or roti.",
        "dietary_restrictions": ["vegetarian"]
    },
    {
        "name": "Upma",
        "cuisine": "Indian",
        "ingredients": ["semolina", "onion", "green chilies", "ginger", "mustard seeds", "curry leaves", "cashew nuts", "vegetables (carrot, peas, beans)", "oil", "salt", "water"],
        "instructions": "Dry roast semolina until lightly golden. In a pan, heat oil and add mustard seeds. When they splutter, add chopped onion, green chilies, ginger, and curry leaves. Saute until onions are translucent. Add chopped vegetables and cook for a few minutes. Add water and salt. Bring to a boil. Gradually add roasted semolina while stirring continuously to avoid lumps. Cook until the mixture thickens. Garnish with roasted cashew nuts. Serve hot.",
        "dietary_restrictions": ["vegetarian", "vegan"]
    },
]

# Combine all recipes
all_recipes = recipes + indian_recipes

# Define function to generate a recipe based on user preferences
def generate_recipe(cuisine=None, dietary_restrictions=None):
    filtered_recipes = all_recipes
    if cuisine:
        filtered_recipes = [recipe for recipe in filtered_recipes if recipe["cuisine"] == cuisine]
    if dietary_restrictions:
        filtered_recipes = [recipe for recipe in filtered_recipes if not set(recipe["dietary_restrictions"]).intersection(dietary_restrictions)]
    if filtered_recipes:
        return random.choice(filtered_recipes)
    else:
        return None

# User input and preferences
cuisine_preference = input("Enter preferred cuisine (e.g., Italian, Indian, Chinese): ")
dietary_restrictions = input("Enter any dietary restrictions (e.g., vegetarian, vegan, gluten-free): ").split(",")

# Generate recipe based on user preferences
generated_recipe = generate_recipe(cuisine=cuisine_preference.strip().capitalize(), dietary_restrictions=[restriction.strip().lower() for restriction in dietary_restrictions])

# Display generated recipe
if generated_recipe:
    print("\nGenerated Recipe:")
    print("Name:", generated_recipe["name"])
    print("Cuisine:", generated_recipe["cuisine"])
    print("Ingredients:", ", ".join(generated_recipe["ingredients"]))
    print("Instructions:", generated_recipe["instructions"])
else:
    print("\nNo recipe found matching the specified preferences.")
# Out:
# Enter preferred cuisine (e.g., Italian, Indian, Chinese): indian
# Enter any dietary restrictions (e.g., vegetarian, vegan, gluten-free): vegan
#
# Generated Recipe:
# Name: Egg Curry
# Cuisine: Indian
# Ingredients: eggs, onion, tomato, ginger, garlic, chili powder, turmeric, coriander powder, garam masala, salt, oil, cilantro
# Instructions: Boil eggs and peel them. In a pan, heat oil and fry sliced onion until golden brown. Add chopped tomatoes, ginger, and garlic paste. Cook until tomatoes are soft. Add chili powder, turmeric, coriander powder, garam masala, and salt. Cook until oil separates. Cut boiled eggs in half and add to the gravy. Cook for a few minutes. Garnish with chopped cilantro. Serve hot with rice or roti.

# %% [markdown]
# **Task 6:**legal research tool that can search and retrieve relevant case

# %%
class LegalDatabase:
    def __init__(self):
        # Dummy case data (replace with actual database)
        self.cases = [
            {"case_name": "Smith v. Jones", "court": "Supreme Court", "date": "2023-01-15", "summary": "Lorem ipsum..."},
            {"case_name": "Doe v. Roe", "court": "District Court", "date": "2022-11-30", "summary": "Lorem ipsum..."},
            {"case_name": "Brown v. Board of Education", "court": "Supreme Court", "date": "1954-05-17", "summary": "Lorem ipsum..."},
            {"case_name": "Miranda v. Arizona", "court": "Supreme Court", "date": "1966-06-13", "summary": "Lorem ipsum..."},
            {"case_name": "Roe v. Wade", "court": "Supreme Court", "date": "1973-01-22", "summary": "Lorem ipsum..."},
            {"case_name": "Marbury v. Madison", "court": "Supreme Court", "date": "1803-02-24", "summary": "Lorem ipsum..."},
            # Add more cases here
        ]

    def search_cases(self, query):
        # Perform a simple keyword search
        results = []
        for case in self.cases:
            if query.lower() in case["case_name"].lower() or query.lower() in case["summary"].lower():
                results.append(case)
        return results

# Example usage
def main():
    legal_db = LegalDatabase()

    # User query
    query = input("Enter your query: ")

    # Search the database
    results = legal_db.search_cases(query)

    # Display results
    if results:
        print("Search Results:")
        for idx, result in enumerate(results, start=1):
            print(f"{idx}. {result['case_name']} ({result['court']}, {result['date']})")
            print(f"Summary: {result['summary']}\n")
    else:
        print("No results found.")

if __name__ == "__main__":
    main()
# Out:
# Enter your query: Miranda v. Arizona
# Search Results:
# 1. Miranda v. Arizona (Supreme Court, 1966-06-13)
# Summary: Lorem ipsum...

# %% [markdown]
# <h1>Task 7:Language translator Using Llama</h1>

# %%
#task 7
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

# Load the model and tokenizer
model = MBartForConditionalGeneration.from_pretrained("SnypzZz/Llama2-13b-Language-translate")
tokenizer = MBart50TokenizerFast.from_pretrained("SnypzZz/Llama2-13b-Language-translate", src_lang="en_XX")

# Function to translate text
def translate_text(input_text, target_language):
    # Tokenize the input text
    model_inputs = tokenizer(input_text, return_tensors="pt")

    # Generate translation
    generated_tokens = model.generate(
        **model_inputs,
        forced_bos_token_id=tokenizer.lang_code_to_id[target_language]
    )

    # Decode the generated tokens
    translated_text = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
    return translated_text

# Main function to take input from user and translate
def main():
    while True:
        input_text = input("Enter the text to translate (type 'exit' to quit): ")
        if input_text.lower() == 'exit':
            print("Exiting...")
            break
        target_language = input("Enter the target language ('hi' for Hindi, 'zh' for Chinese): ")

        # Translate the input text
        translated_text = translate_text(input_text, target_language)

        # Print the translated text
        print("Translated text:", translated_text)

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Enter the text to translate (type 'exit' to quit): How are you
# Enter the target language ('hi' for Hindi, 'zh' for Chinese): hi_IN
# Translated text: आप कैसे हैं
# Enter the text to translate (type 'exit' to quit): i am walking
# Enter the target language ('hi' for Hindi, 'zh' for Chinese): de_DE
# Translated text: ich gehe
# Enter the text to translate (type 'exit' to quit): What are you doing bro
# Enter the target language ('hi' for Hindi, 'zh' for Chinese): hi_IN
# Translated text: तुम क्या कर रहे हो भाई
# Enter the text to translate (type 'exit' to quit): I am studying
# Enter the target language ('hi' for Hindi, 'zh' for Chinese): te_IN
# Translated text: నేనుప్రయాసిస్తున్నారుam
# Enter the text to translate (type 'exit' to quit): Very good
# Enter the target language ('hi' for Hindi, 'zh' for Chinese): te_IN
# Translated text: చాలా మంచి
# Enter the text to translate (type 'exit' to quit): how are you bro
# Enter the target language ('hi' for Hindi, 'zh' for Chinese): ta_IN
# ...

# %% [markdown]
# <h1>Task 8:text summarization

# %%
from transformers import BartForConditionalGeneration, BartTokenizer

# Load BART model and tokenizer
model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")
tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")

def generate_summary(long_text, max_length=150, min_length=40):
    # Tokenize input text
    inputs = tokenizer([long_text], max_length=1024, return_tensors="pt", truncation=True)

    # Generate summary
    summary_ids = model.generate(inputs["input_ids"], max_length=max_length, min_length=min_length, length_penalty=2.0, num_beams=4, early_stopping=True)

    # Decode summary
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

    return summary

if __name__ == "__main__":
    # Example long paragraph
    long_paragraph = """
    Having a best friend by Shaikh Subuhi is one of the best friendship moral stories in English. The story is about two friends who were walking through the desert. During the journey, they argued over something, and one friend slapped the other. The one who got slapped was hurt by this gesture of his best friend but did not react. He quietly wrote in the sand, “Today my best friend slapped me.”

After some time, they found an oasis and started taking a bath in the lake. Suddenly, the one who had been slapped started drowning. Then his friend came to his rescue and saved him. After he recovered from the drowning, he engraved “Today my best friend saved my life” on a stone.

The friend who had slapped earlier and later saved his best friend asked, “After I slapped you, you wrote in the sand, and now, as I saved you, you write on a stone, why?” The other friend replied, “I wrote in on sand because we should not keep the feeling of getting hurt by someone for a long time. But, when someone does something good for us, we must remember it forever like a message engraved on a stone that nothing can erase”.
    """

    # Generate summary
    summary = generate_summary(long_paragraph)

    # Print summary
    print("Summary:")
    print(summary)
# Out:
# Summary:
# Having a best friend by Shaikh Subuhi is one of the best friendship moral stories in English. The story is about two friends who were walking through the desert. During the journey, one friend slapped the other. The one who got slapped was hurt by this gesture of his best friend but did not react.

# %% [markdown]
# <h1>Task 9: Sentiment analysis

# %%
import nltk

# Download the VADER lexicon
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

def analyze_sentiment(text):
    # Initialize VADER sentiment analyzer
    sid = SentimentIntensityAnalyzer()

    # Analyze sentiment
    scores = sid.polarity_scores(text)

    # Classify sentiment
    if scores['compound'] >= 0.05:
        sentiment = "Positive"
    elif scores['compound'] <= -0.05:
        sentiment = "Negative"
    else:
        sentiment = "Neutral"

    return sentiment

if __name__ == "__main__":
    # Example text data
    text_data = [
        "I love this product! It's amazing.",
        "I hate Mondays. They are the worst.",
        "The weather today is okay.",
        "The movie was neither good nor bad.",
        "I feel indifferent about this topic."
    ]

    # Analyze sentiment for each text
    for idx, text in enumerate(text_data, start=1):
        sentiment = analyze_sentiment(text)
        print(f"Text {idx}: {text}")
        print(f"Sentiment: {sentiment}\n")
# Out:
# Text 1: I love this product! It's amazing.
# Sentiment: Positive
#
# Text 2: I hate Mondays. They are the worst.
# Sentiment: Negative
#
# Text 3: The weather today is okay.
# Sentiment: Positive
#
# Text 4: The movie was neither good nor bad.
# Sentiment: Negative
#
# Text 5: I feel indifferent about this topic.
# Sentiment: Negative
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# <h1>Task 10:disney style avatars</h1>

# %%
import requests
import io
from PIL import Image
import matplotlib.pyplot as plt

API_URL = "https://api-inference.huggingface.co/models/stablediffusionapi/disney-pixar-cartoon"
headers = {"Authorization": "Bearer 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"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.content

def generate_avatar(prompt):
    image_bytes = query({"inputs": prompt})
    try:
        image = Image.open(io.BytesIO(image_bytes))
        return image
    except Exception as e:
        print("Error opening image:", e)
        return None

# Define prompts for different characteristics
facial_features = ["big eyes", "small eyes", "round face", "square face"]
hairstyles = ["long hair", "short hair", "curly hair", "straight hair"]
accessories = ["glasses", "hat", "necklace", "bow tie"]

# Generate random prompts combining different characteristics
import random
random_prompt = f"A modern Disney-style character with {random.choice(facial_features)}, {random.choice(hairstyles)}, and {random.choice(accessories)}"

# Generate avatar image based on the random prompt
avatar_image = generate_avatar(random_prompt)
if avatar_image:
    # Display the avatar image
    plt.imshow(avatar_image)
    plt.axis('off')  # Hide axis
    plt.show()

    # Save the avatar image to a file
    avatar_image.save("avatar.jpg")
    print("Avatar image saved as 'avatar.jpg'.")
else:
    print("Failed to generate avatar image.")
# Out:
# Avatar image saved as 'avatar.jpg'.
